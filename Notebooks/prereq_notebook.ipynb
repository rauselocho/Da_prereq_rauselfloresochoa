# %%
print("Hello everyone i struggled up to this point and im still struggling, im keeping my fingers crossed.")
# Out:
# Hello everyone i struggled up to this point and im still struggling, im keeping my fingers crossed.

# %% [markdown]
# Hello, my name is Rausel Flores Ochoa. Lately ive been very excited on trying to learn git, git bash and coding on python. So far i havent had much success since this is my true first solo unsupported experience with python and as for git and git bash i still cant fully understand it yet. And with this i would like my mentor to know that, i would really appreciate it if i could get extra help on git and git bash.s
